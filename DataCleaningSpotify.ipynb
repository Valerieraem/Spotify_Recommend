# %% [markdown]
# ## Data Cleaning for Song Recommendation Project
# ---
# ### Using data collected from spotify api and playlist data from kaggle
# [Kaggle 6K Spotify Playlists](https://www.kaggle.com/datasets/viktoriiashkurenko/278k-spotify-songs)

# %%
import pandas as pd
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %% [markdown]
# ## Import Data From CSV File

# %%
df_features = pd.read_csv('Final_Features_Copy2.csv')
df_tracks = pd.read_csv('duringClean.csv')

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33534 entries, 0 to 33533
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   0                 33534 non-null  object
#  1   Danceability      33534 non-null  object
#  2   Energy            33533 non-null  object
#  3   Key               33533 non-null  object
#  4   Loudness          33533 non-null  object
#  5   Mode              33533 non-null  object
#  6   Speechiness       33533 non-null  object
#  7   Acousticness      33533 non-null  object
#  8   Instrumentalness  33533 non-null  object
#  9   Liveness          33533 non-null  object
#  10  Valence           33533 non-null  object
#  11  Tempo             33533 non-null  object
#  12  Type              33533 non-null  object
#  13  Audio_Features    33533 non-null  object
#  14  URI               33533 non-null  object
#  15  Track_Href        33533 non-null  object
# ...

# %%
df_features.head()
# Out:
#                                                    0            Danceability
# 0  {'danceability': 0.715, 'energy': 0.723, 'key'...  {'danceability': 0.715  \
# 1  {'danceability': 0.584, 'energy': 0.536, 'key'...  {'danceability': 0.584
# 2  {'danceability': 0.55, 'energy': 0.917, 'key':...   {'danceability': 0.55
# 3  {'danceability': 0.663, 'energy': 0.72, 'key':...  {'danceability': 0.663
# 4  {'danceability': 0.522, 'energy': 0.964, 'key'...  {'danceability': 0.522
#
#             Energy        Key            Loudness       Mode
# 0  'energy': 0.723   'key': 6  'loudness': -5.993  'mode': 0  \
# 1  'energy': 0.536  'key': 10  'loudness': -8.158  'mode': 1
# 2  'energy': 0.917   'key': 0  'loudness': -3.159  'mode': 1
# 3   'energy': 0.72   'key': 3  'loudness': -5.497  'mode': 1
# 4  'energy': 0.964  'key': 11  'loudness': -2.645  'mode': 0
#
#              Speechiness             Acousticness
# 0  'speechiness': 0.0569   'acousticness': 0.0396  \
# ...

# %% [markdown]
# #### Want to clean data, remove column 0, remove extra brackets and titles. Check column data types, make a new dataframe with selected columns from track info and features.

# %% [markdown]
# **Removing column 0**

# %%
df_features = df_features.drop(columns = ['0'])
df_features.head()
# Out:
#              Danceability           Energy        Key            Loudness
# 0  {'danceability': 0.715  'energy': 0.723   'key': 6  'loudness': -5.993  \
# 1  {'danceability': 0.584  'energy': 0.536  'key': 10  'loudness': -8.158
# 2   {'danceability': 0.55  'energy': 0.917   'key': 0  'loudness': -3.159
# 3  {'danceability': 0.663   'energy': 0.72   'key': 3  'loudness': -5.497
# 4  {'danceability': 0.522  'energy': 0.964  'key': 11  'loudness': -2.645
#
#         Mode            Speechiness             Acousticness
# 0  'mode': 0  'speechiness': 0.0569   'acousticness': 0.0396  \
# 1  'mode': 1  'speechiness': 0.0279    'acousticness': 0.112
# 2  'mode': 1  'speechiness': 0.0638  'acousticness': 0.00428
# 3  'mode': 1  'speechiness': 0.0331  'acousticness': 0.00212
# 4  'mode': 0   'speechiness': 0.095  'acousticness': 0.00109
#
#                Instrumentalness            Liveness           Valence
# 0  'instrumentalness': 8.57e-05   'liveness': 0.084  'valence': 0.479  \
# ...

# %%
df_features.duplicated().sum()
#There are 10477 duplicates in features (before removal)
# Out:
# 0

# %% [markdown]
# **Making sure that duplicates are based on Audio Features column (track URI)**

# %%
subset_features = df_features.duplicated(subset=['Audio_Features']).sum()
print(subset_features)
# Out:
# 10477

# %% [markdown]
# **Removing duplicates in the dataframe**

# %%
df_features.drop_duplicates(subset=['Audio_Features'], inplace= True)
print(df_features)
# Out:
#                  Danceability           Energy        Key
# 0      {'danceability': 0.715  'energy': 0.723   'key': 6  \
# 1      {'danceability': 0.584  'energy': 0.536  'key': 10
# 2       {'danceability': 0.55  'energy': 0.917   'key': 0
# 3      {'danceability': 0.663   'energy': 0.72   'key': 3
# 4      {'danceability': 0.522  'energy': 0.964  'key': 11
# ...                       ...              ...        ...
# 33529  {'danceability': 0.592  'energy': 0.677   'key': 3
# 33530   {'danceability': 0.65  'energy': 0.665   'key': 9
# 33531  {'danceability': 0.597  'energy': 0.729   'key': 9
# 33532  {'danceability': 0.428  'energy': 0.682   'key': 1
# 33533  {'danceability': 0.344  'energy': 0.796   'key': 9
#
#                   Loudness       Mode            Speechiness
# 0       'loudness': -5.993  'mode': 0  'speechiness': 0.0569  \
# 1       'loudness': -8.158  'mode': 1  'speechiness': 0.0279
# 2       'loudness': -3.159  'mode': 1  'speechiness': 0.0638
# ...

# %% [markdown]
# **Next start cleaning data columns**

# %%
df_features = df_features.reset_index(drop=True)

# %% [markdown]
# **Fixing index values after removing duplicates**

# %%
print(df_features)
# Out:
#                  Danceability           Energy        Key
# 0      {'danceability': 0.715  'energy': 0.723   'key': 6  \
# 1      {'danceability': 0.584  'energy': 0.536  'key': 10
# 2       {'danceability': 0.55  'energy': 0.917   'key': 0
# 3      {'danceability': 0.663   'energy': 0.72   'key': 3
# 4      {'danceability': 0.522  'energy': 0.964  'key': 11
# ...                       ...              ...        ...
# 23052  {'danceability': 0.592  'energy': 0.677   'key': 3
# 23053   {'danceability': 0.65  'energy': 0.665   'key': 9
# 23054  {'danceability': 0.597  'energy': 0.729   'key': 9
# 23055  {'danceability': 0.428  'energy': 0.682   'key': 1
# 23056  {'danceability': 0.344  'energy': 0.796   'key': 9
#
#                   Loudness       Mode            Speechiness
# 0       'loudness': -5.993  'mode': 0  'speechiness': 0.0569  \
# 1       'loudness': -8.158  'mode': 1  'speechiness': 0.0279
# 2       'loudness': -3.159  'mode': 1  'speechiness': 0.0638
# ...

# %%
df_features.head()
# Out:
#              Danceability           Energy        Key            Loudness
# 0  {'danceability': 0.715  'energy': 0.723   'key': 6  'loudness': -5.993  \
# 1  {'danceability': 0.584  'energy': 0.536  'key': 10  'loudness': -8.158
# 2   {'danceability': 0.55  'energy': 0.917   'key': 0  'loudness': -3.159
# 3  {'danceability': 0.663   'energy': 0.72   'key': 3  'loudness': -5.497
# 4  {'danceability': 0.522  'energy': 0.964  'key': 11  'loudness': -2.645
#
#         Mode            Speechiness             Acousticness
# 0  'mode': 0  'speechiness': 0.0569   'acousticness': 0.0396  \
# 1  'mode': 1  'speechiness': 0.0279    'acousticness': 0.112
# 2  'mode': 1  'speechiness': 0.0638  'acousticness': 0.00428
# 3  'mode': 1  'speechiness': 0.0331  'acousticness': 0.00212
# 4  'mode': 0   'speechiness': 0.095  'acousticness': 0.00109
#
#                Instrumentalness            Liveness           Valence
# 0  'instrumentalness': 8.57e-05   'liveness': 0.084  'valence': 0.479  \
# ...

# %%
#saving backup file before changing the data too much, save as csv file called Backup_cleaning.csv
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %%
# df_features['Danceability'] = df_features['Danceability'].str.replace(r'\D', '', regex=True).astype(int)
df_features = pd.read_csv('Backup_cleaning.csv')

# %% [markdown]
# ### Starting to clean each column, remove extra values and save backup csv file periodically.

# %%
df_features['Danceability'] = df_features['Danceability'].str.replace(r'[^0-9.]', '', regex=True)

# %%
df_features['Energy'] = df_features['Energy'].str.replace(r'[^0-9.]', '', regex=True)

# %%
df_features['Key'] = df_features['Key'].str.replace(r'[^0-9.]', '', regex=True)

# %%
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %%
df_features['Loudness'] = df_features['Loudness'].str.replace("'loudness': ", '')

# %%
df_features.head()
# Out:
#   Danceability Energy Key Loudness       Mode            Speechiness
# 0        0.715  0.723   6   -5.993  'mode': 0  'speechiness': 0.0569  \
# 1        0.584  0.536  10   -8.158  'mode': 1  'speechiness': 0.0279
# 2         0.55  0.917   0   -3.159  'mode': 1  'speechiness': 0.0638
# 3        0.663   0.72   3   -5.497  'mode': 1  'speechiness': 0.0331
# 4        0.522  0.964  11   -2.645  'mode': 0   'speechiness': 0.095
#
#               Acousticness              Instrumentalness            Liveness
# 0   'acousticness': 0.0396  'instrumentalness': 8.57e-05   'liveness': 0.084  \
# 1    'acousticness': 0.112         'instrumentalness': 0   'liveness': 0.456
# 2  'acousticness': 0.00428         'instrumentalness': 0   'liveness': 0.197
# 3  'acousticness': 0.00212         'instrumentalness': 0   'liveness': 0.358
# 4  'acousticness': 0.00109  'instrumentalness': 0.000389  'liveness': 0.0387
#
#             Valence             Tempo                      Type
# ...

# %%
df_features['Mode'] = df_features['Mode'].str.replace("'mode': ", '')

# %%
df_features['Speechiness'] = df_features['Speechiness'].str.replace("'speechiness': ", '')

# %%
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %%
df_features['Acousticness'] = df_features['Acousticness'].str.replace("'acousticness': ", '')

# %%
df_features['Instrumentalness'] = df_features['Instrumentalness'].str.replace("'instrumentalness': ", '')

# %%
df_features['Liveness'] = df_features['Liveness'].str.replace("'liveness': ", '')

# %%
df_features['Valence'] = df_features['Valence'].str.replace("'valence': ", '')

# %%
df_features['Tempo'] = df_features['Tempo'].str.replace("'tempo': ", '')

# %%
df_features['Type'] = df_features['Type'].str.replace("'type': ", '')

# %%
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %%
df_features.head()
# Out:
#   Danceability Energy Key Loudness Mode Speechiness Acousticness
# 0        0.715  0.723   6   -5.993    0      0.0569       0.0396  \
# 1        0.584  0.536  10   -8.158    1      0.0279        0.112
# 2         0.55  0.917   0   -3.159    1      0.0638      0.00428
# 3        0.663   0.72   3   -5.497    1      0.0331      0.00212
# 4        0.522  0.964  11   -2.645    0       0.095      0.00109
#
#   Instrumentalness Liveness Valence    Tempo              Type
# 0         8.57e-05    0.084   0.479  114.985  'audio_features'  \
# 1                0    0.456    0.44  126.996  'audio_features'
# 2                0    0.197   0.601  126.115  'audio_features'
# 3                0    0.358   0.608  135.342  'audio_features'
# 4         0.000389   0.0387    0.51  170.944  'audio_features'
#
#                    Audio_Features
# 0  'id': '1s9xuJxhYM0LdVqksjegcg'  \
# 1  'id': '6J7cSyvSCnPwv3vqHchEfL'
# 2  'id': '6TfBA04WJ3X1d1wXhaCFVT'
# 3  'id': '65mxB9IWpmVo4qUjdGSxRB'
# ...

# %%
df_features['Audio_Features'] = df_features['Audio_Features'].str.replace("'id': ", '')

# %%
df_features['URI'] = df_features['URI'].str.replace("'uri': ", '')

# %%
df_features['Track_Href'] = df_features['Track_Href'].str.replace("'track_href': ", '')

# %%
df_features['Analysis_URL'] = df_features['Analysis_URL'].str.replace("'analysis_url': ", '')

# %%
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %%
df_features['Duration_MS'] = df_features['Duration_MS'].str.replace("'duration_ms': ", '')

# %%
df_features['Time_Sig'] = df_features['Time_Sig'].str.replace("'time_signature': ", '')

# %%
df_features['Time_Sig'] = df_features['Time_Sig'].str.replace("}", '')

# %%
df_features.head()
# Out:
#   Danceability Energy Key Loudness Mode Speechiness Acousticness
# 0        0.715  0.723   6   -5.993    0      0.0569       0.0396  \
# 1        0.584  0.536  10   -8.158    1      0.0279        0.112
# 2         0.55  0.917   0   -3.159    1      0.0638      0.00428
# 3        0.663   0.72   3   -5.497    1      0.0331      0.00212
# 4        0.522  0.964  11   -2.645    0       0.095      0.00109
#
#   Instrumentalness Liveness Valence    Tempo              Type
# 0         8.57e-05    0.084   0.479  114.985  'audio_features'  \
# 1                0    0.456    0.44  126.996  'audio_features'
# 2                0    0.197   0.601  126.115  'audio_features'
# 3                0    0.358   0.608  135.342  'audio_features'
# 4         0.000389   0.0387    0.51  170.944  'audio_features'
#
#              Audio_Features                                     URI
# 0  '1s9xuJxhYM0LdVqksjegcg'  'spotify:track:1s9xuJxhYM0LdVqksjegcg'  \
# ...

# %%
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Cleaning complete, change variable types for each column

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23057 entries, 0 to 23056
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Danceability      23057 non-null  object
#  1   Energy            23056 non-null  object
#  2   Key               23056 non-null  object
#  3   Loudness          23056 non-null  object
#  4   Mode              23056 non-null  object
#  5   Speechiness       23056 non-null  object
#  6   Acousticness      23056 non-null  object
#  7   Instrumentalness  23056 non-null  object
#  8   Liveness          23056 non-null  object
#  9   Valence           23056 non-null  object
#  10  Tempo             23056 non-null  object
#  11  Type              23056 non-null  object
#  12  Audio_Features    23056 non-null  object
#  13  URI               23056 non-null  object
#  14  Track_Href        23056 non-null  object
#  15  Analysis_URL      23056 non-null  object
# ...

# %%
df_features['Danceability'] = df_features['Danceability'].astype(float)

# %%
df_features['Energy'] = df_features['Energy'].astype(float)
#df_features['Key'] = df_features['Key'].astype(int)
df_features['Loudness'] = df_features['Loudness'].astype(float)
#df_features['Mode'] = df_features['Mode'].astype(int)
df_features['Speechiness'] = df_features['Speechiness'].astype(float)
df_features['Acousticness'] = df_features['Acousticness'].astype(float)
df_features['Instrumentalness'] = df_features['Instrumentalness'].astype(float)
df_features['Liveness'] = df_features['Liveness'].astype(float)
df_features['Valence'] = df_features['Valence'].astype(float)
df_features['Tempo'] = df_features['Tempo'].astype(float)
#df_features['Duration_MS'] = df_features['Duration_MS'].astype(int)
#df_features['Time_Sig'] = df_features['Time_Sig'].astype(int)

# %%
df_features['Key'] = df_features['Key'].astype(int)
df_features['Mode'] = df_features['Mode'].astype(int)
df_features['Duration_MS'] = df_features['Duration_MS'].astype(int)
df_features['Time_Sig'] = df_features['Time_Sig'].astype(int)

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23057 entries, 0 to 23056
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Danceability      23057 non-null  float64
#  1   Energy            23056 non-null  float64
#  2   Key               23056 non-null  object
#  3   Loudness          23056 non-null  float64
#  4   Mode              23056 non-null  object
#  5   Speechiness       23056 non-null  float64
#  6   Acousticness      23056 non-null  float64
#  7   Instrumentalness  23056 non-null  float64
#  8   Liveness          23056 non-null  float64
#  9   Valence           23056 non-null  float64
#  10  Tempo             23056 non-null  float64
#  11  Type              23056 non-null  object
#  12  Audio_Features    23056 non-null  object
#  13  URI               23056 non-null  object
#  14  Track_Href        23056 non-null  object
#  15  Analysis_URL      23056 non-null  object
# ...

# %%
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %%
is_numeric_dtype(df_features['Mode'])
#now the data type is numeric
# Out:
# True

# %% [markdown]
# **Datatype is not changing, check what is wrong. The error was stating that there a null values.**

# %%
df_features.isnull().values.any()
# Out:
# True

# %%
df_features = df_features.dropna()

# %%
df_features.isnull().values.any()
# Out:
# False

# %% [markdown]
# **No more NULL values in the dataframe, data types successfully changed**

# %%
df_features.to_csv('Backup_cleaning.csv', encoding='utf-8', index=False)

# %% [markdown]
# ### Cleaning complete and data should be ready to use
